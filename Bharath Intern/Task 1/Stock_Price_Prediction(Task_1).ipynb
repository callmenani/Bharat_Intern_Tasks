# %% [markdown]
# # Data Science @Bharat-Intern

# %% [markdown]
# # Done By Harsha Vardhan

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('Google_Stock.csv') # importing the data
df.head(10)
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %%
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']]
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0]))
df.set_index('date',drop=True,inplace=True)
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
training_size = round(len(df) * 0.75)
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %%
model = Sequential()

model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30,902
# Trainable params: 30,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 7s 98ms/step - loss: 0.0077 - mean_absolute_error: 0.0604 - val_loss: 0.0124 - val_mean_absolute_error: 0.0892
# Epoch 2/100
# 28/28 [==============================] - 2s 86ms/step - loss: 7.7463e-04 - mean_absolute_error: 0.0219 - val_loss: 0.0062 - val_mean_absolute_error: 0.0626
# Epoch 3/100
# 28/28 [==============================] - 2s 76ms/step - loss: 4.7846e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0042 - val_mean_absolute_error: 0.0503
# Epoch 4/100
# 28/28 [==============================] - 2s 63ms/step - loss: 4.9564e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0041 - val_mean_absolute_error: 0.0492
# Epoch 5/100
# 28/28 [==============================] - 2s 62ms/step - loss: 4.3763e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0034 - val_mean_absolute_error: 0.0443
# Epoch 6/100
# 28/28 [==============================] - 2s 62ms/step - loss: 4.6218e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0054 - val_mean_absolute_error: 0.0582
# Epoch 7/100
# 28/28 [==============================] - 2s 61ms/step - loss: 4.2639e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0038 - val_mean_absolute_error: 0.0470
# Epoch 8/100
# 28/28 [==============================] - 2s 62ms/step - loss: 4.0365e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0061 - val_mean_absolute_error: 0.0631
# Epoch 9/100
# 28/28 [==============================] - 3s 97ms/step - loss: 4.1644e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0034 - val_mean_absolute_error: 0.0441
# Epoch 10/100
# 28/28 [==============================] - 2s 66ms/step - loss: 4.0317e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0030 - val_mean_absolute_error: 0.0406
# Epoch 11/100
# 28/28 [==============================] - 2s 62ms/step - loss: 3.8071e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0046 - val_mean_absolute_error: 0.0536
# Epoch 12/100
# 28/28 [==============================] - 2s 62ms/step - loss: 3.7372e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0037 - val_mean_absolute_error: 0.0465
# Epoch 13/100
# 28/28 [==============================] - 2s 62ms/step - loss: 3.6237e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0047 - val_mean_absolute_error: 0.0533
# Epoch 14/100
# 28/28 [==============================] - 2s 62ms/step - loss: 3.4868e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0051 - val_mean_absolute_error: 0.0561
# Epoch 15/100
# 28/28 [==============================] - 2s 67ms/step - loss: 3.5568e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0037 - val_mean_absolute_error: 0.0452
# Epoch 16/100
# 28/28 [==============================] - 3s 100ms/step - loss: 3.5125e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0052 - val_mean_absolute_error: 0.0569
# Epoch 17/100
# 28/28 [==============================] - 2s 62ms/step - loss: 3.1965e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0043 - val_mean_absolute_error: 0.0498
# Epoch 18/100
# 28/28 [==============================] - 2s 61ms/step - loss: 3.3675e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0060 - val_mean_absolute_error: 0.0613
# Epoch 19/100
# 28/28 [==============================] - 2s 61ms/step - loss: 3.0591e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0062 - val_mean_absolute_error: 0.0618
# Epoch 20/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.9171e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0064 - val_mean_absolute_error: 0.0625
# Epoch 21/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.9481e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0072 - val_mean_absolute_error: 0.0677
# Epoch 22/100
# 28/28 [==============================] - 2s 76ms/step - loss: 3.0077e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0077 - val_mean_absolute_error: 0.0708
# Epoch 23/100
# 28/28 [==============================] - 2s 89ms/step - loss: 2.9011e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0049 - val_mean_absolute_error: 0.0533
# Epoch 24/100
# 28/28 [==============================] - 2s 62ms/step - loss: 3.0030e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0067 - val_mean_absolute_error: 0.0640
# Epoch 25/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.7004e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0049 - val_mean_absolute_error: 0.0524
# Epoch 26/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.9431e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0034 - val_mean_absolute_error: 0.0431
# Epoch 27/100
# 28/28 [==============================] - 2s 62ms/step - loss: 3.6854e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0077 - val_mean_absolute_error: 0.0747
# Epoch 28/100
# 28/28 [==============================] - 2s 62ms/step - loss: 3.3013e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0035 - val_mean_absolute_error: 0.0448
# Epoch 29/100
# 28/28 [==============================] - 2s 82ms/step - loss: 2.6294e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0047 - val_mean_absolute_error: 0.0535
# Epoch 30/100
# 28/28 [==============================] - 2s 81ms/step - loss: 2.5555e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0044 - val_mean_absolute_error: 0.0515
# Epoch 31/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.5151e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0039 - val_mean_absolute_error: 0.0487
# Epoch 32/100
# 28/28 [==============================] - 2s 76ms/step - loss: 2.5085e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0036 - val_mean_absolute_error: 0.0464
# Epoch 33/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.5831e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0025 - val_mean_absolute_error: 0.0360
# Epoch 34/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.5830e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0024 - val_mean_absolute_error: 0.0346
# Epoch 35/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.5237e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0045 - val_mean_absolute_error: 0.0503
# Epoch 36/100
# 28/28 [==============================] - 3s 101ms/step - loss: 2.2828e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0061 - val_mean_absolute_error: 0.0607
# Epoch 37/100
# 28/28 [==============================] - 2s 64ms/step - loss: 2.2626e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0036 - val_mean_absolute_error: 0.0440
# Epoch 38/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.3169e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0043 - val_mean_absolute_error: 0.0504
# Epoch 39/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.7395e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0028 - val_mean_absolute_error: 0.0389
# Epoch 40/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.3518e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0062 - val_mean_absolute_error: 0.0632
# Epoch 41/100
# 28/28 [==============================] - 2s 63ms/step - loss: 2.1502e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0034 - val_mean_absolute_error: 0.0433
# Epoch 42/100
# 28/28 [==============================] - 2s 66ms/step - loss: 2.1583e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0046 - val_mean_absolute_error: 0.0532
# Epoch 43/100
# 28/28 [==============================] - 3s 103ms/step - loss: 2.1152e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0029 - val_mean_absolute_error: 0.0396
# Epoch 44/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.4623e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0018 - val_mean_absolute_error: 0.0307
# Epoch 45/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.0988e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0027 - val_mean_absolute_error: 0.0392
# Epoch 46/100
# 28/28 [==============================] - 2s 63ms/step - loss: 2.1086e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0029 - val_mean_absolute_error: 0.0402
# Epoch 47/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.2258e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0052 - val_mean_absolute_error: 0.0593
# Epoch 48/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.1547e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0032 - val_mean_absolute_error: 0.0433
# Epoch 49/100
# 28/28 [==============================] - 2s 79ms/step - loss: 2.0156e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0029 - val_mean_absolute_error: 0.0394
# Epoch 50/100
# 28/28 [==============================] - 2s 84ms/step - loss: 1.9570e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0052 - val_mean_absolute_error: 0.0579
# Epoch 51/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.9598e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0023 - val_mean_absolute_error: 0.0348
# Epoch 52/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.8106e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0026 - val_mean_absolute_error: 0.0387
# Epoch 53/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.0410e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0030 - val_mean_absolute_error: 0.0424
# Epoch 54/100
# 28/28 [==============================] - 2s 79ms/step - loss: 1.6955e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0026 - val_mean_absolute_error: 0.0391
# Epoch 55/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.9094e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0015 - val_mean_absolute_error: 0.0281
# Epoch 56/100
# 28/28 [==============================] - 3s 96ms/step - loss: 1.7858e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0019 - val_mean_absolute_error: 0.0339
# Epoch 57/100
# 28/28 [==============================] - 2s 77ms/step - loss: 1.6351e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0033 - val_mean_absolute_error: 0.0444
# Epoch 58/100
# 28/28 [==============================] - 2s 85ms/step - loss: 1.7247e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0029 - val_mean_absolute_error: 0.0412
# Epoch 59/100
# 28/28 [==============================] - 2s 85ms/step - loss: 1.5210e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0022 - val_mean_absolute_error: 0.0344
# Epoch 60/100
# 28/28 [==============================] - 2s 83ms/step - loss: 1.5647e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0022 - val_mean_absolute_error: 0.0353
# Epoch 61/100
# 28/28 [==============================] - 2s 72ms/step - loss: 1.7492e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0018 - val_mean_absolute_error: 0.0308
# Epoch 62/100
# 28/28 [==============================] - 3s 95ms/step - loss: 1.5216e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0026 - val_mean_absolute_error: 0.0385
# Epoch 63/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.5524e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0025 - val_mean_absolute_error: 0.0386
# Epoch 64/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.5201e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0020 - val_mean_absolute_error: 0.0336
# Epoch 65/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.6238e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0027 - val_mean_absolute_error: 0.0396
# Epoch 66/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.3732e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0015 - val_mean_absolute_error: 0.0280
# Epoch 67/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.3763e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0016 - val_mean_absolute_error: 0.0292
# Epoch 68/100
# 28/28 [==============================] - 2s 83ms/step - loss: 1.4037e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0029 - val_mean_absolute_error: 0.0422
# Epoch 69/100
# 28/28 [==============================] - 2s 82ms/step - loss: 1.3706e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0016 - val_mean_absolute_error: 0.0292
# Epoch 70/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.4059e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0026 - val_mean_absolute_error: 0.0404
# Epoch 71/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.3749e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0019 - val_mean_absolute_error: 0.0340
# Epoch 72/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.3895e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0025 - val_mean_absolute_error: 0.0397
# Epoch 73/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.3000e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0018 - val_mean_absolute_error: 0.0324
# Epoch 74/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.2732e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0027 - val_mean_absolute_error: 0.0409
# Epoch 75/100
# 28/28 [==============================] - 2s 87ms/step - loss: 1.3118e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0026 - val_mean_absolute_error: 0.0407
# Epoch 76/100
# 28/28 [==============================] - 2s 77ms/step - loss: 1.2419e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0017 - val_mean_absolute_error: 0.0323
# Epoch 77/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.3023e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0018 - val_mean_absolute_error: 0.0315
# Epoch 78/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.2041e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0020 - val_mean_absolute_error: 0.0350
# Epoch 79/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.2038e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0020 - val_mean_absolute_error: 0.0343
# Epoch 80/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.2065e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0013 - val_mean_absolute_error: 0.0269
# Epoch 81/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.1457e-04 - mean_absolute_error: 0.0076 - val_loss: 8.7510e-04 - val_mean_absolute_error: 0.0213
# Epoch 82/100
# 28/28 [==============================] - 3s 99ms/step - loss: 1.2368e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0016 - val_mean_absolute_error: 0.0290
# Epoch 83/100
# 28/28 [==============================] - 2s 69ms/step - loss: 1.2258e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0024 - val_mean_absolute_error: 0.0385
# Epoch 84/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.1869e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0019 - val_mean_absolute_error: 0.0334
# Epoch 85/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.1450e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0027 - val_mean_absolute_error: 0.0403
# Epoch 86/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.2149e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0026 - val_mean_absolute_error: 0.0404
# Epoch 87/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.2317e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0021 - val_mean_absolute_error: 0.0376
# Epoch 88/100
# 28/28 [==============================] - 2s 73ms/step - loss: 1.3803e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0014 - val_mean_absolute_error: 0.0277
# Epoch 89/100
# 28/28 [==============================] - 3s 93ms/step - loss: 1.2019e-04 - mean_absolute_error: 0.0080 - val_loss: 7.2882e-04 - val_mean_absolute_error: 0.0191
# Epoch 90/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.2093e-04 - mean_absolute_error: 0.0079 - val_loss: 7.5443e-04 - val_mean_absolute_error: 0.0194
# Epoch 91/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.1182e-04 - mean_absolute_error: 0.0075 - val_loss: 8.5064e-04 - val_mean_absolute_error: 0.0208
# Epoch 92/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.1253e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0016 - val_mean_absolute_error: 0.0297
# Epoch 93/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.0639e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0010 - val_mean_absolute_error: 0.0232
# Epoch 94/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.1892e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0015 - val_mean_absolute_error: 0.0284
# Epoch 95/100
# 28/28 [==============================] - 2s 87ms/step - loss: 1.0384e-04 - mean_absolute_error: 0.0072 - val_loss: 0.0014 - val_mean_absolute_error: 0.0282
# Epoch 96/100
# 28/28 [==============================] - 2s 87ms/step - loss: 1.0305e-04 - mean_absolute_error: 0.0072 - val_loss: 0.0014 - val_mean_absolute_error: 0.0289
# Epoch 97/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.0547e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0012 - val_mean_absolute_error: 0.0250
# Epoch 98/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.0126e-04 - mean_absolute_error: 0.0072 - val_loss: 0.0016 - val_mean_absolute_error: 0.0324
# Epoch 99/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.0237e-04 - mean_absolute_error: 0.0072 - val_loss: 7.8070e-04 - val_mean_absolute_error: 0.0203
# Epoch 100/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.0447e-04 - mean_absolute_error: 0.0072 - val_loss: 8.7232e-04 - val_mean_absolute_error: 0.0208

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 2s 30ms/step
# array([[0.41044712, 0.4126559 ],
#        [0.4094599 , 0.4115072 ],
#        [0.40534687, 0.40727264],
#        [0.4103477 , 0.412193  ],
#        [0.41390288, 0.41581792]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1431.9362, 1433.0518],
#        [1430.1058, 1430.9227],
#        [1422.4807, 1423.0747],
#        [1431.7518, 1432.1938],
#        [1438.3428, 1438.912 ]], dtype=float32)

# %% [markdown]
# # Comparing Predicted Data

# %%
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1431.936157      1433.051758
# 2020-05-28  1396.86  1416.73     1430.105835      1430.922729
# 2020-05-29  1416.94  1428.92     1422.480713      1423.074707
# 2020-06-01  1418.39  1431.82     1431.751831      1432.193848
# 2020-06-02  1430.55  1439.22     1438.342773      1438.911987

# %%
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# # Prediction For Next 10 Days

# %%
df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2432.127930      2356.553467
# 2021-06-10  2494.01  2521.60     2440.968262      2365.456299
# 2021-06-11  2524.92  2513.93     2454.351807      2379.111816
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 52ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
